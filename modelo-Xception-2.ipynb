# %% [markdown]
# # Caderno com o modelo 1 - partição 1 - Xception

# %% [markdown]
# - Paper do Xception:  https://arxiv.org/abs/1610.02357

# %% [markdown]
# - O trabalho busca classificar imagens de pessoas nas seguintes classes:
#
#
# 1.   pessoas sem máscara
# 2.   pessoas com máscara incorreta
# 3.   pessoas com máscara correta

# %%
# Usaremos a GPU
import tensorflow as tf

# %%
# tf.test.is_gpu_available()
len(tf.config.list_physical_devices('GPU'))
# Out:
# 1

# %%
print(tf.__version__)
# Out:
# 2.6.0

# %% [markdown]
# # Bibliotecas

# %%
#from tensorflow.keras.optimizers import RMSprop
from keras.preprocessing.image import ImageDataGenerator
import cv2
from keras.models import Sequential
from keras.layers import Conv2D, Input, ZeroPadding2D, BatchNormalization,Activation, MaxPooling2D, Flatten, Dense,Dropout
from keras.models import Model, load_model
from keras.callbacks import TensorBoard, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.utils import shuffle
import imutils
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns
import pandas as pd
from PIL import Image
import pathlib

# %%
AUTOTUNE = tf.data.AUTOTUNE

# %% [markdown]
# - Carregando o dataset de treino

# %%
dataset = os.path.join(os.getcwd(), 'D:/TCC/1/p1') 

tamanho_treinamento_com_errada = len(os.listdir(os.path.join(dataset,'incorreta')))
tamanho_treinamento_com_certa = len(os.listdir(os.path.join(dataset,'correta')))
tamanho_treinamento_sem = len(os.listdir(os.path.join(dataset,'sem')))

print("Classe 1 - sem: " + str(tamanho_treinamento_sem))
print("Classe 2 - incorreta: " + str(tamanho_treinamento_com_errada))
print("Classe 3 - correta: " + str(tamanho_treinamento_com_certa))
# Out:
# Classe 1 - sem: 8000
# Classe 2 - incorreta: 7624
# Classe 3 - correta: 7683

# %%
ditribuicao_dataset = {'1-Sem': [tamanho_treinamento_sem],'2-Incorreta': [tamanho_treinamento_com_errada],'3-Correta':[tamanho_treinamento_com_certa]}
# Criando um dataframe
df_ditribuicao_dataset = pd.DataFrame(ditribuicao_dataset, index=['total'])
df_ditribuicao_dataset
# Out:
#        1-Sem  2-Incorreta  3-Correta
# total   8000         7624       7683

# %% [markdown]
# # Hiper-parâmetros

# %% [markdown]
# - imagem

# %%
image_width = 150
image_height = 150
image_color_channel = 3
image_size = (image_width, image_height)
image_shape = image_size + (image_color_channel,)
image_color_channel_size = 255
batch_size = 32

# %% [markdown]
# # Pré-processamento

# %% [markdown]
# o 1º problema é que algumas fotos podem estar corrompidas. Iremos excluí-las conforme
# ensinado em https://keras.io/examples/vision/image_classification_from_scratch/

# %% [markdown]
# Adotaremos a separação do conjunto original em 3 partes: Treinamento, Validação e Teste.
#
# - O conjunto de Treinamento será utilizado para o processo de aprendizado,
# - O conjunto de Validação será utilizado para o ajuste de parâmetros, depois de cada época,
# - O conjunto de Teste será utilizado para avaliar o modelo final.
#
# Para isso, o conjunto de treinamento será separado em 90% como treinamento e 10% como validação

# %% [markdown]
# ### Forma: meu próprio pipeline

# %% [markdown]
# - Construir manualmente um tf.data.Dataset semelhante ao criado por tf.keras.utils.image_dataset_from_directory
# - Aqui, conseguirei dividir o dataset em treino e teste

# %% [markdown]
# - Segui o descrito em: https://www.tensorflow.org/tutorials/load_data/images

# %%
data_dir_1 = pathlib.Path(dataset)
data_dir_1
# Out:
# WindowsPath('D:/TCC/1/p1')

# %%
image_count = len(list(data_dir_1.glob('*/*')))   #ou .jpg
print(image_count)
# Out:
# 23307

# %%
list_ds = tf.data.Dataset.list_files(str(data_dir_1) + '/*/*', shuffle=True)
list_ds = list_ds.shuffle(image_count, reshuffle_each_iteration=False)

# %%
for f in list_ds.take(5):
  print(f.numpy())
# Out:
# b'D:\\TCC\\1\\p1\\incorreta\\00940_Mask_Mouth_Chin.jpg'
# b'D:\\TCC\\1\\p1\\correta\\57694_Mask.jpg'
# b'D:\\TCC\\1\\p1\\sem\\21959.jpg'
# b'D:\\TCC\\1\\p1\\sem\\15851.jpg'
# b'D:\\TCC\\1\\p1\\incorreta\\01148_Mask_Mouth_Chin.jpg'

# %% [markdown]
# Usando a estrutura em árvore (nome das pastas) como classe:

# %%
class_names = np.array(sorted([item.name for item in data_dir_1.glob('*') if item.name != "LICENSE.txt"]))
print(class_names)
# Out:
# ['correta' 'incorreta' 'sem']

# %%
#Estamos com o dataset de treino, ele será dividido em treinamento (80%) e validação (20%)
val_size = int(image_count * 0.2)
train_ds = list_ds.skip(val_size)
val_ds = list_ds.take(val_size)

# %%
# Podemos obter a caredinalidade de um dataset de duas formas

print(tf.data.experimental.cardinality(train_ds).numpy())
print(tf.data.experimental.cardinality(val_ds).numpy())
# Out:
# 18646
# 4661

# %% [markdown]
# - Função curta que converta um caminho de arquivo em um par (img, label) :

# %%
def get_label(file_path):
  # Convert the path to a list of path components
  parts = tf.strings.split(file_path, os.path.sep)
  # The second to last is the class-directory
  one_hot = parts[-2] == class_names
  # Integer encode the label
  return tf.argmax(one_hot)

# %%
def decode_img(img):
  # Convert the compressed string to a 3D uint8 tensor
  img = tf.io.decode_jpeg(img, channels=3)
  # Resize the image to the desired size
  return tf.image.resize(img, [image_height, image_width])

# %%
def process_path(file_path):
  label = get_label(file_path)
  # Load the raw data from the file as a string
  img = tf.io.read_file(file_path)
  img = decode_img(img)
  return img, label

# %% [markdown]
# - criar conjunto image, label

# %%
# Set `num_parallel_calls` so multiple images are loaded/processed in parallel.
train_ds = train_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
for image, label in train_ds.take(1):
  print("Image shape: ", image.numpy().shape)
  print("Label: ", label.numpy())
# Out:
# Image shape:  (150, 150, 3)
# Label:  0

# %% [markdown]
# - Configurar conjunto de dados para desempenho

# %%
def configure_for_performance(ds):
  ds = ds.cache()
  ds = ds.shuffle(buffer_size=1000)
  ds = ds.batch(batch_size)
  ds = ds.prefetch(buffer_size=AUTOTUNE)
  return ds

# %%
train_ds = configure_for_performance(train_ds)
val_ds = configure_for_performance(val_ds)

# %% [markdown]
# - Plotar algumas imagens

# %%
#

# %%
def plotar_imagens(dataset):
  plt.gcf().clear()
  plt.figure(figsize = (10, 10))
  for imagem, rotulo in dataset.take(1):
    for i in range(6):
      ax = plt.subplot(3, 3, i + 1)
      plt.imshow(imagem[i].numpy().astype('uint8'))
      plt.title(class_names[rotulo[i]])
      plt.axis('off')

# %%
plotar_imagens(train_ds)

# %% [markdown]
# # Modelo

# %% [markdown]
# - HP do modelo

# %%
tx_aprendizagem = 0.001
epocas = 50

# %% [markdown]
# - Podemos criar uma camada de normalização das imagens:

# %%
# normalization_layer = tf.keras.layers.Rescaling(1./255, input_shape =image_shape)

# %% [markdown]
# - questão de cache das memórias

# %%
train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# Criação do modelo propriamente falando:

# %%
num_classes = 3

# %% [markdown]
# https://www.tensorflow.org/api_docs/python/tf/keras/applications/xception/Xception

# %% [markdown]
# O diferencial dessa abordagem é que iremos primeiro congelar o modelo pré-treinado, depois treinamos o que foi adicionado. Por fim, treinamos tudo, inclusive o modelo importado, mas com uma tx aprendizado pequena.

# %%
modelo_treinado= tf.keras.applications.xception.Xception(
    include_top=False,
    input_shape=(150, 150, 3),
    weights='imagenet',
    pooling=None,
    classes=num_classes,
    classifier_activation='softmax'
)


#Congelando esse modelo
modelo_treinado.trainable = False

#Normalização do pixel
inputs = tf.keras.Input(shape=(150, 150, 3))
normalizacao = tf.keras.layers.Rescaling(scale=1 / 127.5, offset=-1)
x = normalizacao(inputs)

#Construcao do modelo
# model = Sequential()
# model.add(modelo_treinado)
# )
# model.add()    
# model.add()
    
x = modelo_treinado(x, training=False)
x = tf.keras.layers.Flatten()(x)
x = tf.keras.layers.Dropout(0.2)(x)  # Regularize with dropout
x = tf.keras.layers.Dense(150, activation='relu')(x)
outputs = tf.keras.layers.Dense(num_classes, activation='softmax')(x)
model = tf.keras.Model(inputs, outputs)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# rescaling (Rescaling)        (None, 150, 150, 3)       0
# _________________________________________________________________
# xception (Functional)        (None, 5, 5, 2048)        20861480
# _________________________________________________________________
# flatten (Flatten)            (None, 51200)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 51200)             0
# _________________________________________________________________
# dense (Dense)                (None, 150)               7680150
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 453
# =================================================================
# Total params: 28,542,083
# Trainable params: 7,680,603
# Non-trainable params: 20,861,480
# _________________________________________________________________

# %%
#otimização
opt = Adam(learning_rate=tx_aprendizagem)

# %%
# METRICS = [
#     tf.keras.metrics.Accuracy(name="acc"),
#     tf.keras.metrics.Precision(name="precision"),
#     tf.keras.metrics.Recall(name="recall"),
# ]

# %%
model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics='acc')   #METRICS)
model.summary()

#sparse_categorical_crossentropy ou 'categorical_crossentropy' na função perda
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# rescaling (Rescaling)        (None, 150, 150, 3)       0
# _________________________________________________________________
# xception (Functional)        (None, 5, 5, 2048)        20861480
# _________________________________________________________________
# flatten (Flatten)            (None, 51200)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 51200)             0
# _________________________________________________________________
# dense (Dense)                (None, 150)               7680150
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 453
# =================================================================
# Total params: 28,542,083
# Trainable params: 7,680,603
# Non-trainable params: 20,861,480
# _________________________________________________________________

# %% [markdown]
# # Treinamento

# %% [markdown]
# - Treinando...

# %% [markdown]
# Existem várias maneiras de combater o overfitting no processo de treinamento, p.e.:
# - o aumento de dados
# - adicionará Dropout ao seu modelo.
#
# - Cair fora
# Outra técnica para reduzir o overfitting é introduzir a regularização de dropout na rede.
#
# Quando você aplica dropout a uma camada, ela descarta aleatoriamente (definindo a ativação como zero) um número de unidades de saída da camada durante o processo de treinamento. Dropout recebe um número fracionário como valor de entrada, na forma de 0,1, 0,2, 0,4, etc. Isso significa descartar 10%, 20% ou 40% das unidades de saída aleatoriamente da camada aplicada.

# %% [markdown]
# ##### ATENÇÃO: Caso esteja carregando o modelo salvo, não há necessidade de executar algumas das células a seguir (p.e. treinar o modelo ou salvá-lo).

# %% [markdown]
# - Treinando só o novo

# %%
#Treinando...
model.fit(train_ds, epochs=epocas, validation_data=val_ds)
# Out:
# Epoch 1/50
# 583/583 [==============================] - 429s 695ms/step - loss: 0.3427 - acc: 0.9358 - val_loss: 0.1005 - val_acc: 0.9663
# Epoch 2/50
# 583/583 [==============================] - 90s 154ms/step - loss: 0.0769 - acc: 0.9717 - val_loss: 0.0844 - val_acc: 0.9691
# Epoch 3/50
# 583/583 [==============================] - 78s 135ms/step - loss: 0.0603 - acc: 0.9785 - val_loss: 0.1236 - val_acc: 0.9549
# Epoch 4/50
# 583/583 [==============================] - 79s 135ms/step - loss: 0.0563 - acc: 0.9802 - val_loss: 0.0451 - val_acc: 0.9848
# Epoch 5/50
# 583/583 [==============================] - 79s 135ms/step - loss: 0.0463 - acc: 0.9835 - val_loss: 0.0259 - val_acc: 0.9916
# Epoch 6/50
# 583/583 [==============================] - 79s 135ms/step - loss: 0.0440 - acc: 0.9845 - val_loss: 0.0323 - val_acc: 0.9882
# Epoch 7/50
# 583/583 [==============================] - 79s 135ms/step - loss: 0.0313 - acc: 0.9892 - val_loss: 0.0268 - val_acc: 0.9912
# Epoch 8/50
# 583/583 [==============================] - 80s 137ms/step - loss: 0.0291 - acc: 0.9902 - val_loss: 0.0484 - val_acc: 0.9837
# Epoch 9/50
# 583/583 [==============================] - 79s 136ms/step - loss: 0.0316 - acc: 0.9893 - val_loss: 0.0304 - val_acc: 0.9908
# Epoch 10/50
# 583/583 [==============================] - 79s 136ms/step - loss: 0.0286 - acc: 0.9906 - val_loss: 0.0211 - val_acc: 0.9933
# Epoch 11/50
# 583/583 [==============================] - 79s 136ms/step - loss: 0.0257 - acc: 0.9902 - val_loss: 0.0286 - val_acc: 0.9914
# Epoch 12/50
# 583/583 [==============================] - 79s 136ms/step - loss: 0.0288 - acc: 0.9898 - val_loss: 0.0229 - val_acc: 0.9946
# Epoch 13/50
# 583/583 [==============================] - 79s 136ms/step - loss: 0.0272 - acc: 0.9908 - val_loss: 0.0217 - val_acc: 0.9944
# Epoch 14/50
# 583/583 [==============================] - 79s 136ms/step - loss: 0.0193 - acc: 0.9935 - val_loss: 0.0208 - val_acc: 0.9961
# Epoch 15/50
# 583/583 [==============================] - 79s 136ms/step - loss: 0.0188 - acc: 0.9937 - val_loss: 0.0152 - val_acc: 0.9959
# Epoch 16/50
# 583/583 [==============================] - 79s 135ms/step - loss: 0.0141 - acc: 0.9952 - val_loss: 0.0149 - val_acc: 0.9966
# Epoch 17/50
# 583/583 [==============================] - 79s 135ms/step - loss: 0.0153 - acc: 0.9945 - val_loss: 0.0157 - val_acc: 0.9961
# Epoch 18/50
# 583/583 [==============================] - 79s 135ms/step - loss: 0.0200 - acc: 0.9939 - val_loss: 0.0212 - val_acc: 0.9951
# Epoch 19/50
# 583/583 [==============================] - 79s 135ms/step - loss: 0.0146 - acc: 0.9959 - val_loss: 0.0278 - val_acc: 0.9908
# Epoch 20/50
# 583/583 [==============================] - 79s 135ms/step - loss: 0.0096 - acc: 0.9964 - val_loss: 0.0150 - val_acc: 0.9964
# Epoch 21/50
# 583/583 [==============================] - 79s 136ms/step - loss: 0.0075 - acc: 0.9972 - val_loss: 0.0180 - val_acc: 0.9957
# Epoch 22/50
# 583/583 [==============================] - 78s 134ms/step - loss: 0.0138 - acc: 0.9958 - val_loss: 0.0171 - val_acc: 0.9961
# Epoch 23/50
# 583/583 [==============================] - 79s 135ms/step - loss: 0.0130 - acc: 0.9961 - val_loss: 0.0569 - val_acc: 0.9848
# Epoch 24/50
# 583/583 [==============================] - 79s 135ms/step - loss: 0.0088 - acc: 0.9969 - val_loss: 0.0312 - val_acc: 0.9931
# Epoch 25/50
# 583/583 [==============================] - 78s 134ms/step - loss: 0.0156 - acc: 0.9950 - val_loss: 0.0161 - val_acc: 0.9957
# Epoch 26/50
# 583/583 [==============================] - 79s 135ms/step - loss: 0.0149 - acc: 0.9955 - val_loss: 0.0224 - val_acc: 0.9933
# Epoch 27/50
# 583/583 [==============================] - 79s 135ms/step - loss: 0.0120 - acc: 0.9961 - val_loss: 0.0227 - val_acc: 0.9957
# Epoch 28/50
# 583/583 [==============================] - 78s 134ms/step - loss: 0.0121 - acc: 0.9965 - val_loss: 0.0241 - val_acc: 0.9951
# Epoch 29/50
# 583/583 [==============================] - 78s 134ms/step - loss: 0.0118 - acc: 0.9960 - val_loss: 0.0174 - val_acc: 0.9961
# Epoch 30/50
# 583/583 [==============================] - 79s 135ms/step - loss: 0.0050 - acc: 0.9987 - val_loss: 0.0186 - val_acc: 0.9966
# Epoch 31/50
# 583/583 [==============================] - 78s 134ms/step - loss: 0.0048 - acc: 0.9981 - val_loss: 0.0163 - val_acc: 0.9959
# Epoch 32/50
# 583/583 [==============================] - 78s 134ms/step - loss: 0.0133 - acc: 0.9959 - val_loss: 0.0397 - val_acc: 0.9951
# Epoch 33/50
# 583/583 [==============================] - 79s 135ms/step - loss: 0.0099 - acc: 0.9971 - val_loss: 0.0182 - val_acc: 0.9976
# Epoch 34/50
# 583/583 [==============================] - 77s 133ms/step - loss: 0.0048 - acc: 0.9987 - val_loss: 0.0220 - val_acc: 0.9959
# Epoch 35/50
# 583/583 [==============================] - 79s 135ms/step - loss: 0.0123 - acc: 0.9957 - val_loss: 0.0217 - val_acc: 0.9968
# Epoch 36/50
# 583/583 [==============================] - 79s 135ms/step - loss: 0.0046 - acc: 0.9984 - val_loss: 0.0201 - val_acc: 0.9972
# Epoch 37/50
# 583/583 [==============================] - 78s 134ms/step - loss: 0.0061 - acc: 0.9979 - val_loss: 0.0250 - val_acc: 0.9957
# Epoch 38/50
# 583/583 [==============================] - 78s 134ms/step - loss: 0.0054 - acc: 0.9984 - val_loss: 0.0311 - val_acc: 0.9949
# Epoch 39/50
# 583/583 [==============================] - 79s 135ms/step - loss: 0.0101 - acc: 0.9966 - val_loss: 0.0231 - val_acc: 0.9959
# Epoch 40/50
# 583/583 [==============================] - 77s 133ms/step - loss: 0.0052 - acc: 0.9986 - val_loss: 0.0374 - val_acc: 0.9955
# Epoch 41/50
# 583/583 [==============================] - 78s 135ms/step - loss: 0.0104 - acc: 0.9970 - val_loss: 0.0382 - val_acc: 0.9953
# Epoch 42/50
# 583/583 [==============================] - 78s 135ms/step - loss: 0.0061 - acc: 0.9981 - val_loss: 0.0285 - val_acc: 0.9970
# Epoch 43/50
# 583/583 [==============================] - 78s 134ms/step - loss: 0.0085 - acc: 0.9974 - val_loss: 0.0282 - val_acc: 0.9966
# Epoch 44/50
# 583/583 [==============================] - 79s 135ms/step - loss: 0.0108 - acc: 0.9972 - val_loss: 0.0266 - val_acc: 0.9955
# Epoch 45/50
# 583/583 [==============================] - 77s 133ms/step - loss: 0.0078 - acc: 0.9975 - val_loss: 0.0302 - val_acc: 0.9951
# Epoch 46/50
# 583/583 [==============================] - 78s 135ms/step - loss: 0.0134 - acc: 0.9967 - val_loss: 0.0208 - val_acc: 0.9968
# Epoch 47/50
# 583/583 [==============================] - 78s 134ms/step - loss: 0.0075 - acc: 0.9978 - val_loss: 0.0335 - val_acc: 0.9933
# Epoch 48/50
# 583/583 [==============================] - 78s 134ms/step - loss: 0.0017 - acc: 0.9995 - val_loss: 0.0200 - val_acc: 0.9974
# Epoch 49/50
# 583/583 [==============================] - 78s 134ms/step - loss: 0.0049 - acc: 0.9984 - val_loss: 0.0198 - val_acc: 0.9968
# Epoch 50/50
# 583/583 [==============================] - 77s 133ms/step - loss: 0.0041 - acc: 0.9986 - val_loss: 0.0316 - val_acc: 0.9959

# %% [markdown]
# - Treinando tudo

# %%
modelo_treinado.trainable = True
model.summary()
tx_aprendizagem2 = 0.00001
opt = Adam(learning_rate=tx_aprendizagem2)
model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics='acc')   #METRICS)


#Salvando o melhor modelo
checkpoint = ModelCheckpoint('model2-{epoch:03d}.model',monitor='val_accuracy',verbose=0,save_best_only=True,mode='auto')


#Treinando...
history = model.fit(train_ds,
                              epochs=20,
                              validation_data=val_ds,
                              callbacks=[checkpoint])
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# rescaling (Rescaling)        (None, 150, 150, 3)       0
# _________________________________________________________________
# xception (Functional)        (None, 5, 5, 2048)        20861480
# _________________________________________________________________
# flatten (Flatten)            (None, 51200)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 51200)             0
# _________________________________________________________________
# dense (Dense)                (None, 150)               7680150
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 453
# =================================================================
# Total params: 28,542,083
# Trainable params: 28,487,555
# Non-trainable params: 54,528
# _________________________________________________________________
# Epoch 1/20
# 583/583 [==============================] - 291s 489ms/step - loss: 0.0125 - acc: 0.9973 - val_loss: 0.0104 - val_acc: 0.9985
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 2/20
# 583/583 [==============================] - 287s 493ms/step - loss: 0.0064 - acc: 0.9981 - val_loss: 0.0107 - val_acc: 0.9983
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 3/20
# 583/583 [==============================] - 287s 493ms/step - loss: 0.0065 - acc: 0.9989 - val_loss: 0.0052 - val_acc: 0.9987
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 4/20
# 583/583 [==============================] - 287s 492ms/step - loss: 0.0044 - acc: 0.9989 - val_loss: 0.0036 - val_acc: 0.9994
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 5/20
# 583/583 [==============================] - 287s 492ms/step - loss: 3.6282e-04 - acc: 0.9998 - val_loss: 9.5822e-04 - val_acc: 0.9998
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 6/20
# 583/583 [==============================] - 286s 491ms/step - loss: 0.0051 - acc: 0.9992 - val_loss: 0.0039 - val_acc: 0.9989
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 7/20
# 583/583 [==============================] - 289s 495ms/step - loss: 0.0062 - acc: 0.9992 - val_loss: 2.4785e-04 - val_acc: 1.0000
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 8/20
# 583/583 [==============================] - 286s 491ms/step - loss: 0.0034 - acc: 0.9994 - val_loss: 0.0041 - val_acc: 0.9991
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 9/20
# 583/583 [==============================] - 287s 492ms/step - loss: 0.0028 - acc: 0.9994 - val_loss: 0.0129 - val_acc: 0.9974
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 10/20
# 583/583 [==============================] - 286s 491ms/step - loss: 0.0033 - acc: 0.9997 - val_loss: 2.3028e-04 - val_acc: 1.0000
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 11/20
# 583/583 [==============================] - 286s 491ms/step - loss: 0.0023 - acc: 0.9993 - val_loss: 0.0032 - val_acc: 0.9989
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 12/20
# 583/583 [==============================] - 286s 491ms/step - loss: 0.0023 - acc: 0.9994 - val_loss: 5.4195e-04 - val_acc: 0.9996
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 13/20
# 583/583 [==============================] - 286s 491ms/step - loss: 0.0037 - acc: 0.9991 - val_loss: 1.9520e-04 - val_acc: 1.0000
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 14/20
# 583/583 [==============================] - 286s 491ms/step - loss: 0.0015 - acc: 0.9994 - val_loss: 0.0032 - val_acc: 0.9991
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 15/20
# 583/583 [==============================] - 286s 490ms/step - loss: 2.3692e-04 - acc: 0.9999 - val_loss: 3.8032e-04 - val_acc: 0.9998
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 16/20
# 583/583 [==============================] - 286s 491ms/step - loss: 1.0932e-04 - acc: 0.9999 - val_loss: 2.2530e-04 - val_acc: 0.9998
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 17/20
# 583/583 [==============================] - 286s 491ms/step - loss: 7.9573e-05 - acc: 0.9999 - val_loss: 4.9059e-04 - val_acc: 0.9998
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 18/20
# 583/583 [==============================] - 286s 490ms/step - loss: 1.3303e-04 - acc: 0.9999 - val_loss: 4.3123e-04 - val_acc: 0.9998
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 19/20
# 583/583 [==============================] - 286s 491ms/step - loss: 6.9916e-04 - acc: 0.9998 - val_loss: 0.0017 - val_acc: 0.9998
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 20/20
# 583/583 [==============================] - 286s 490ms/step - loss: 0.0031 - acc: 0.9992 - val_loss: 0.0056 - val_acc: 0.9985
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.

# %%
#Plotar o desempenho
def processo_treinamento():
  accuracy = history.history['acc']
  val_accuracy = history.history['val_acc']
  loss = history.history['loss']
  val_loss = history.history['val_loss']
  epochs_range = range(20)
  plt.gcf().clear()
  plt.figure(figsize = (15, 8))
  plt.subplot(1, 2, 1)
  plt.title('Evolução da Acurácia ao Longo do treinamento')
  plt.plot(epochs_range, accuracy, label = 'Training Accuracy')
  plt.plot(epochs_range, val_accuracy, label = 'Validation Accuracy')
  plt.legend(loc = 'lower right')
  plt.subplot(1, 2, 2)
  plt.title('Evolução da Loss ao Longo do treinamento')
  plt.plot(epochs_range, loss, label = 'Training Loss')
  plt.plot(epochs_range, val_loss, label = 'Validation Loss')
  plt.legend(loc = 'lower right')
  plt.savefig("processo-treinamento-Xception_abordagem3.png", dpi=300)
  plt.show()

# %%
processo_treinamento()  #seria o caso de plotar as outras métricas?

# %% [markdown]
# # Salvar o modelo

# %%
model.save('modelos/model_p1_Xception_ab3')
# Out:
# INFO:tensorflow:Assets written to: modelos/model_p1_Xception_ab3\assets
# C:\Users\jlvol\anaconda3\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %% [markdown]
# ##### ATENÇÃO: Caso esteja carregando o modelo salvo, não há necessidade de executar algumas das células acima (p.e. treinar o modelo ou salvá-lo).

# %% [markdown]
# # Importando o modelo

# %%
model = load_model('modelos/model_p1_Xception_ab3')

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# rescaling (Rescaling)        (None, 150, 150, 3)       0
# _________________________________________________________________
# xception (Functional)        (None, 5, 5, 2048)        20861480
# _________________________________________________________________
# flatten (Flatten)            (None, 51200)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 51200)             0
# _________________________________________________________________
# dense (Dense)                (None, 150)               7680150
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 453
# =================================================================
# Total params: 28,542,083
# Trainable params: 28,487,555
# Non-trainable params: 54,528
# _________________________________________________________________

# %% [markdown]
# ### Aplicando o modelo a um dataset de teste

# %% [markdown]
# - Nosso dataset de teste:

# %%
# dataset_teste = os.path.join('D:/TCC/1/teste', '')
dataset_teste = os.path.join('D:/artigo/mix', '') #Onde estão a pasta train (p1) e test (p1-teste)
# Dataset

# %%
data_dir_teste= pathlib.Path(dataset_teste)
data_dir_teste
# Out:
# WindowsPath('D:/artigo/mix')

# %%
image_count_t = len(list(data_dir_teste.glob('*/*')))   #ou .jpg
print(image_count_t)
# Out:
# 150

# %%
list_t = tf.data.Dataset.list_files(str(data_dir_teste) + '/*/*', shuffle=False)
list_t = list_t.shuffle(image_count_t, reshuffle_each_iteration=False)

# %%
for f1 in list_t.take(3):
  print(f1.numpy())
# Out:
# b'D:\\artigo\\mix\\correta\\112_mask.jpg'
# b'D:\\artigo\\mix\\sem\\69008.png'
# b'D:\\artigo\\mix\\incorreta\\train_00002846.jpg'

# %%
class_names = np.array(sorted([item.name for item in data_dir_1.glob('*') if item.name != "LICENSE.txt"]))
print(class_names)
# Out:
# ['correta' 'incorreta' 'sem']

# %%
val_size_t = int(image_count_t *0)
teste = list_t.skip(val_size_t)
print(tf.data.experimental.cardinality(teste).numpy())
# Out:
# 150

# %%
# Set `num_parallel_calls` so multiple images are loaded/processed in parallel.
teste  = teste.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
for image, label in teste.take(1):
  print("Image shape: ", image.numpy().shape)
  print("Label: ", label.numpy())
# Out:
# Image shape:  (150, 150, 3)
# Label:  0

# %%
#  Configurar conjunto de dados para desempenho
teste = configure_for_performance(teste)

#  questão de cache das memórias
teste =  teste.cache().prefetch(buffer_size=AUTOTUNE)

# %%
plotar_imagens(teste)

# %%
# teste = tf.keras.utils.image_dataset_from_directory(
#   data_dir_teste,
#   image_size=(image_height, image_width),
#   batch_size=batch_size)

# %%
classe_real = pd.DataFrame(columns=["real"])
ponteiro = 0
for data in teste.as_numpy_iterator():
    a = class_names[data[1]]
    for i in range(a.size):  # de 0 a 31  
        classe_real.loc[i+ponteiro] = a[i]
    ponteiro= classe_real.shape[0]

# %%
classe_real
# Out:
#           real
# 0      correta
# 1      correta
# 2          sem
# 3    incorreta
# 4      correta
# ..         ...
# 145        sem
# 146        sem
# 147    correta
# 148  incorreta
# 149  incorreta
#
# [150 rows x 1 columns]

# %%
predictions = model.predict(teste)
print(predictions)
# Out:
# [[9.97600973e-01 2.39574024e-03 3.35892992e-06]
#  [9.99999166e-01 8.11187306e-07 3.83753305e-13]
#  [1.43227037e-22 2.15352824e-14 1.00000000e+00]
#  [1.07837209e-12 9.99975324e-01 2.47335211e-05]
#  [1.00000000e+00 6.67446709e-10 3.07393059e-19]
#  [9.31680972e-08 9.99944210e-01 5.56824016e-05]
#  [1.00000000e+00 1.11187992e-08 7.20566627e-17]
#  [5.68505973e-02 9.36445236e-01 6.70406874e-03]
#  [1.35498019e-02 9.85954344e-01 4.95884044e-04]
#  [9.99989748e-01 1.02922622e-05 6.17993434e-11]
#  [1.43322273e-20 1.90579893e-15 1.00000000e+00]
#  [5.65188087e-12 9.99999881e-01 8.10782979e-08]
#  [1.12152383e-01 8.87335122e-01 5.12486731e-04]
#  [1.16137337e-18 3.09399536e-15 1.00000000e+00]
#  [1.00000000e+00 3.31945991e-08 6.42329701e-16]
#  [1.00000000e+00 3.85002030e-10 8.63549676e-20]
#  [4.44466891e-18 2.00488023e-13 1.00000000e+00]
#  [1.21185652e-16 1.00000000e+00 1.66946923e-09]
#  [1.16374693e-24 5.11377013e-19 1.00000000e+00]
#  [2.73349032e-09 6.10472402e-03 9.93895233e-01]
#  [9.94971633e-01 5.01365401e-03 1.47509563e-05]
#  [1.37969892e-22 1.05467196e-16 1.00000000e+00]
#  [3.03573165e-19 1.00000000e+00 4.66614117e-12]
#  [2.44964258e-16 8.14500342e-11 1.00000000e+00]
#  [1.84538754e-16 9.99999881e-01 6.59224781e-08]
#  [9.99997616e-01 2.39182191e-06 3.46078071e-12]
#  [4.93289078e-21 1.74344964e-16 1.00000000e+00]
#  [2.44882181e-30 5.57239732e-18 1.00000000e+00]
#  [9.99783576e-01 2.16480053e-04 2.73569256e-08]
#  [9.99999762e-01 2.42483424e-07 3.42849291e-14]
#  [1.00000000e+00 1.09758432e-10 7.01717832e-21]
#  [1.00000000e+00 1.20137089e-09 1.77392356e-20]
#  [5.12170808e-22 5.73084708e-18 1.00000000e+00]
#  [9.99764740e-01 2.35226413e-04 3.23009957e-08]
#  [1.00000000e+00 1.66514500e-08 1.61616520e-16]
#  [9.99999523e-01 4.29325155e-07 1.14035829e-13]
#  [7.47491066e-20 2.68853787e-13 1.00000000e+00]
#  [6.36927903e-30 2.43666070e-23 1.00000000e+00]
#  [3.41352113e-02 9.63234723e-01 2.63011199e-03]
#  [7.56531765e-16 1.00000000e+00 3.98200539e-09]
#  [8.77235323e-07 7.22040296e-01 2.77958840e-01]
#  [9.99769747e-01 2.30281788e-04 3.09570787e-08]
#  [6.15709198e-14 5.98207178e-11 1.00000000e+00]
#  [9.99999642e-01 3.34761779e-07 6.53475280e-14]
#  [9.56683993e-01 4.22274210e-02 1.08860317e-03]
#  [1.42209573e-21 4.30293652e-14 1.00000000e+00]
#  [9.36186492e-01 6.14570566e-02 2.35642353e-03]
#  [5.25807436e-12 1.00000000e+00 2.27721220e-08]
#  [9.99998331e-01 1.62621268e-06 1.54242981e-12]
#  [9.93845522e-01 6.14837511e-03 5.99762916e-06]
#  [1.13226376e-01 8.62199485e-01 2.45741028e-02]
#  [4.87730425e-08 8.36094245e-02 9.16390538e-01]
#  [2.96435597e-12 9.99999762e-01 2.03760450e-07]
#  [1.00000000e+00 1.01030096e-11 5.94359424e-23]
#  [1.90237688e-06 9.91469443e-01 8.52868427e-03]
#  [3.51308609e-33 2.35831422e-25 1.00000000e+00]
#  [5.26557613e-29 2.13112225e-23 1.00000000e+00]
#  [9.52470183e-01 4.62198928e-02 1.30996946e-03]
#  [5.98652810e-02 9.32757795e-01 7.37691531e-03]
#  [9.94200110e-01 5.78018185e-03 1.96218170e-05]
#  [1.40617448e-10 9.99996662e-01 3.27919383e-06]
#  [1.68849311e-07 9.99992490e-01 7.34002606e-06]
#  [1.53235644e-01 7.97290862e-01 4.94735502e-02]
#  [4.46488763e-27 5.36448506e-18 1.00000000e+00]
#  [1.82679206e-01 8.12665582e-01 4.65524616e-03]
#  [1.61121500e-25 1.88252245e-18 1.00000000e+00]
#  [2.34972133e-12 5.97697763e-05 9.99940276e-01]
#  [9.99674439e-01 3.25435773e-04 6.18347613e-08]
#  [7.80319097e-04 9.47230637e-01 5.19891419e-02]
#  [9.74853218e-01 2.47790031e-02 3.67828499e-04]
#  [4.52267779e-10 7.44337072e-08 9.99999881e-01]
#  [2.21792901e-22 3.38242391e-17 1.00000000e+00]
#  [2.61668480e-19 8.58804842e-15 1.00000000e+00]
#  [9.48328733e-01 5.15492447e-02 1.22028447e-04]
#  [8.00825894e-18 1.71908305e-13 1.00000000e+00]
#  [4.76285592e-02 9.47533607e-01 4.83789667e-03]
#  [9.99599397e-01 4.00478166e-04 9.36493549e-08]
#  [2.86206055e-27 8.59943023e-21 1.00000000e+00]
#  [1.69958636e-01 8.22039962e-01 8.00138805e-03]
#  [1.00000000e+00 2.25936914e-09 2.97466721e-18]
#  [9.99996543e-01 3.48015305e-06 7.06468608e-12]
#  [9.99304056e-01 6.95883355e-04 3.81051564e-08]
#  [9.99999762e-01 2.82094845e-07 4.64021081e-14]
#  [9.99994755e-01 5.21341417e-06 1.58549718e-11]
#  [2.98222515e-24 1.09559646e-19 1.00000000e+00]
#  [2.95066026e-27 3.99190850e-23 1.00000000e+00]
#  [1.00000000e+00 2.38283612e-12 3.30560921e-24]
#  [1.52751353e-11 1.99216053e-01 8.00783932e-01]
#  [6.20046832e-19 1.49476141e-14 1.00000000e+00]
#  [5.34142045e-12 9.99874711e-01 1.25229766e-04]
#  [8.50021483e-14 1.00000000e+00 9.48204804e-09]
#  [1.15381028e-16 5.81334036e-10 1.00000000e+00]
#  [4.85307996e-21 4.07549056e-15 1.00000000e+00]
#  [1.44646345e-15 1.00000000e+00 5.87342189e-11]
#  [9.99999166e-01 8.47753029e-07 4.19132123e-13]
#  [3.58831447e-14 9.99402046e-01 5.97931736e-04]
#  [9.99960423e-01 3.95721909e-05 9.13766951e-10]
#  [9.82299745e-01 1.75178424e-02 1.82437056e-04]
#  [9.99775231e-01 2.24821997e-04 2.95063316e-08]
#  [1.00000000e+00 8.79531586e-11 4.50586323e-21]
#  [1.81031714e-15 5.69902944e-14 1.00000000e+00]
#  [9.36959028e-01 6.17178418e-02 1.32313289e-03]
#  [8.31244799e-26 1.64318715e-18 1.00000000e+00]
#  [6.22530701e-19 1.70570413e-14 1.00000000e+00]
#  [2.17438489e-02 9.77189600e-01 1.06662884e-03]
#  [1.73612846e-32 2.87249972e-24 1.00000000e+00]
#  [3.47545185e-21 1.00000000e+00 1.97147024e-15]
#  [3.18341776e-22 2.37385307e-13 1.00000000e+00]
#  [9.99877214e-01 1.22770187e-04 1.10270051e-08]
#  [9.99691010e-01 3.09027906e-04 5.91310894e-08]
#  [6.77927769e-10 9.99992371e-01 7.61493266e-06]
#  [1.00000000e+00 6.39505227e-10 2.38275502e-19]
#  [7.38684685e-05 9.19443071e-01 8.04830268e-02]
#  [9.99258935e-01 7.41088064e-04 4.48386253e-08]
#  [3.84929564e-20 9.08879905e-15 1.00000000e+00]
#  [1.85767330e-12 9.99980450e-01 1.95014873e-05]
#  [2.97861232e-15 1.62381485e-01 8.37618530e-01]
#  [8.98877025e-23 1.23561925e-12 1.00000000e+00]
#  [1.81804076e-01 7.54432023e-01 6.37639910e-02]
#  [1.79131791e-28 1.46220847e-22 1.00000000e+00]
#  [9.95842159e-01 4.14774381e-03 1.00865800e-05]
#  [1.28666734e-24 4.15210856e-19 1.00000000e+00]
#  [2.70322339e-13 9.65106306e-09 1.00000000e+00]
#  [1.00000000e+00 7.67756247e-10 3.43437532e-19]
#  [9.99997139e-01 2.83519626e-06 4.68867219e-12]
#  [1.47948968e-13 7.61814817e-07 9.99999285e-01]
#  [2.39843112e-19 1.55840185e-11 1.00000000e+00]
#  [9.99863148e-01 1.36815303e-04 1.71721375e-08]
#  [9.99940872e-01 5.91007993e-05 2.03832595e-09]
#  [5.57741768e-25 1.27423653e-16 1.00000000e+00]
#  [7.53479961e-13 9.99986649e-01 1.33637186e-05]
#  [6.46603644e-01 3.48395765e-01 5.00064064e-03]
#  [5.41719964e-15 1.00000000e+00 5.60161340e-08]
#  [4.95498170e-06 9.99118626e-01 8.76358012e-04]
#  [3.20074856e-20 1.85196758e-12 1.00000000e+00]
#  [1.00000000e+00 2.76196982e-10 4.44405401e-20]
#  [6.57887134e-10 4.36660238e-02 9.56333995e-01]
#  [4.16389114e-04 9.82505083e-01 1.70785096e-02]
#  [1.73961285e-20 1.46421896e-13 1.00000000e+00]
#  [5.94874632e-22 4.00256822e-15 1.00000000e+00]
#  [1.00000000e+00 1.08500098e-08 6.86146781e-17]
#  [2.27481939e-20 2.85636450e-14 1.00000000e+00]
#  [4.62152457e-28 9.94139527e-22 1.00000000e+00]
#  [7.96276612e-21 3.03828983e-13 1.00000000e+00]
#  [9.99678493e-01 3.21497209e-04 2.72521881e-08]
#  [1.24564870e-18 3.96885910e-12 1.00000000e+00]
#  [4.35651674e-21 6.10532180e-10 1.00000000e+00]
#  [1.00000000e+00 1.93241343e-11 2.26951243e-22]
#  [7.24541187e-01 2.75447816e-01 1.09677958e-05]
#  [4.96934582e-09 9.99849558e-01 1.50371401e-04]]

# %%
def predicao(predictions):  #predictions é a saída da função predict
    score1 = tf.nn.softmax(predictions)    
    # score1.shape[0]  é a quantidade de predições
    classe = pd.DataFrame(columns=["predito","confianca"])
    for i in range(score1.shape[0]):
        classe.loc[i] = [class_names[np.argmax(score1[i])],100*np.max(score1[i])]   
    return classe

# %%
def get_labels_from_tfdataset(tfdataset, batched=False):
    labels = list(map(lambda x: x[1], tfdataset)) # Get labels 
    if not batched:
         return tf.concat(labels, axis=0) # concat the list of batched labels
    return class_names[labels]

# %%
get_labels_from_tfdataset(teste)
# Out:
# <tf.Tensor: shape=(150,), dtype=int64, numpy=
# array([0, 0, 2, 1, 0, 1, 0, 1, 0, 0, 2, 1, 1, 2, 0, 0, 2, 1, 2, 1, 0, 2,
#        1, 2, 1, 0, 2, 2, 0, 0, 0, 1, 2, 1, 0, 0, 2, 2, 0, 1, 1, 0, 2, 0,
#        0, 2, 0, 1, 0, 1, 1, 2, 1, 0, 1, 2, 2, 1, 0, 0, 1, 1, 0, 2, 1, 2,
#        1, 0, 1, 1, 1, 2, 2, 1, 2, 1, 0, 2, 1, 0, 0, 0, 0, 0, 2, 2, 0, 1,
#        2, 1, 1, 2, 2, 1, 0, 1, 0, 0, 0, 0, 2, 1, 2, 2, 1, 2, 1, 2, 0, 0,
#        1, 0, 1, 1, 2, 1, 2, 2, 0, 2, 0, 2, 2, 0, 0, 2, 2, 0, 0, 2, 1, 1,
#        1, 1, 2, 0, 1, 1, 2, 2, 0, 2, 2, 2, 1, 2, 2, 0, 1, 1], dtype=int64)>

# %%
classe_predita = predicao(predictions)
classe_predita
# Out:
#        predito  confianca
# 0      correta  57.523769
# 1      correta  57.611656
# 2          sem  57.611686
# 3    incorreta  57.610786
# 4      correta  57.611686
# ..         ...        ...
# 145        sem  57.611686
# 146        sem  57.611686
# 147    correta  57.611686
# 148    correta  47.108513
# 149  incorreta  57.606179
#
# [150 rows x 2 columns]

# %%
resultado_df = pd.concat([classe_real, classe_predita],axis=1)
resultado_df
# Out:
#           real    predito  confianca
# 0      correta    correta  57.523769
# 1      correta    correta  57.611656
# 2          sem        sem  57.611686
# 3    incorreta  incorreta  57.610786
# 4      correta    correta  57.611686
# ..         ...        ...        ...
# 145        sem        sem  57.611686
# 146        sem        sem  57.611686
# 147    correta    correta  57.611686
# 148  incorreta    correta  47.108513
# 149  incorreta  incorreta  57.606179
#
# [150 rows x 3 columns]

# %% [markdown]
# - Avaliação

# %%
model.evaluate(teste, return_dict=True)
# Out:
# 5/5 [==============================] - 1s 104ms/step - loss: 0.7725 - acc: 0.8600
# {'loss': 0.7725188136100769, 'acc': 0.8600000143051147}

# %%
dataset_test_loss, dataset_test_accuracy = model.evaluate(teste)
print('Dataset Test Loss: %s' % dataset_test_loss)
print('Dataset Test Accuracy: %s' % dataset_test_accuracy)
# Out:
# 5/5 [==============================] - 1s 102ms/step - loss: 0.7725 - acc: 0.8600
# Dataset Test Loss: 0.7725188136100769
# Dataset Test Accuracy: 0.8600000143051147

# %% [markdown]
# ### Outras métricas de avaliação

# %%
# Criando o dataframe da Matriz 
Matriz = pd.DataFrame(np.zeros(9).reshape((3, 3)),
                    index=['sem_r', 'incorreta_r', 'correta_r'],
                    columns=['sem_p', 'incorreta_p', 'correta_p'])
Matriz   
#Classe predita p
#Classe real r
    
# Classe 1 - sem:
# Classe 2 - incorreta:
# Classe 3 - correta:
# Out:
#              sem_p  incorreta_p  correta_p
# sem_r          0.0          0.0        0.0
# incorreta_r    0.0          0.0        0.0
# correta_r      0.0          0.0        0.0

# %%
def compara(x,Matriz):
    if (x['real']=='sem' and  x['predito']=='sem'):
        Matriz.iloc[0,0]=Matriz.iloc[0,0]+1
        return 
    if (x['real']=='incorreta' and  x['predito']=='sem'):
        Matriz.iloc[1,0]=Matriz.iloc[1,0]+1
        return 
    if (x['real']=='correta' and  x['predito']=='sem'):
        Matriz.iloc[2,0]=Matriz.iloc[2,0]+1
        return 
    if (x['real']=='sem' and  x['predito']=='incorreta'):
        Matriz.iloc[0,1]=Matriz.iloc[0,1]+1
        return 
    if (x['real']=='incorreta' and  x['predito']=='incorreta'):
        Matriz.iloc[1,1]=Matriz.iloc[1,1]+1
        return 
    if (x['real']=='correta' and  x['predito']=='incorreta'):
        Matriz.iloc[2,1]=Matriz.iloc[2,1]+1
        return 
    if (x['real']=='sem' and  x['predito']=='correta'):
        Matriz.iloc[0,2]=Matriz.iloc[0,2]+1 
        return 
    if (x['real']=='incorreta' and  x['predito']=='correta'):
        Matriz.iloc[1,2]=Matriz.iloc[1,2]+1
        return 
    if (x['real']=='correta' and  x['predito']=='correta'):
        Matriz.iloc[2,2]=Matriz.iloc[2,2]+1
        return 
    
# Matriz.iloc[0,0]=Matriz.iloc[0,0]+1    # sem_p e sem_r
# Matriz.iloc[1,0]=Matriz.iloc[1,0]+1    # sem_p e incorreta_r
# Matriz.iloc[2,0]=Matriz.iloc[2,0]+1    # sem_p e correta_r
# Matriz.iloc[0,1]=Matriz.iloc[0,1]+1    # incorreta_p e sem_r
# Matriz.iloc[1,1]=Matriz.iloc[1,1]+1    # incorreta_p e incorreta_r
# Matriz.iloc[2,1]=Matriz.iloc[2,1]+1    # incorreta_p e correta_r
# Matriz.iloc[0,2]=Matriz.iloc[0,2]+1    # correta_p e  sem_r
# Matriz.iloc[1,2]=Matriz.iloc[1,2]+1   # correta_p e  incorreta_r
# Matriz.iloc[2,2]=Matriz.iloc[2,2]+1   # correta_p e  correta_r

# %%
resultado_df.apply(compara, axis=1, Matriz=Matriz)
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 145    None
# 146    None
# 147    None
# 148    None
# 149    None
# Length: 150, dtype: object

# %%
Matriz
# Out:
#              sem_p  incorreta_p  correta_p
# sem_r         50.0          0.0        0.0
# incorreta_r    5.0         34.0       11.0
# correta_r      0.0          5.0       45.0

# %%
def metricas(data_frame):  
    A = data_frame.iloc[0,0]
    B = data_frame.iloc[0,1]
    C = data_frame.iloc[0,2]
    D = data_frame.iloc[1,0]
    E = data_frame.iloc[1,1] 
    F = data_frame.iloc[1,2]
    G = data_frame.iloc[2,0]
    H = data_frame.iloc[2,1]
    I = data_frame.iloc[2,2]
    total = A +B +C +D +E +F+ G+H+I
    acuracia_total = (A+E+I)/total
    acuracia_sem = (A +E+F+H+I)/total
    acuracia_incorreta= (E+A+C+G+I)/total
    acuracia_correta = (I+A+B+D+E)/total
    print("acuracia_total: " + str(acuracia_total))

    #PRECISAO = VP/ (VP + FP)
    precisao_sem = A/(A+D+ G)
    precisao_incorreta = E/(E+B+H)
    precisao_correta = I/(I+C+F)
    print("precisao_sem: " + str(precisao_sem))
    print("precisao_incorreta : " + str(precisao_incorreta))
    print("precisao_correta: " + str(precisao_correta))
    
    #REVOCAÇÃO = VP / (VP + FN)
    revocacao_sem = A/(A+B+C)
    revocacao_incorreta = E/(E+F+D)
    revocacao_correta = I/(I+G+H)
    print("revocacao_sem: " + str(revocacao_sem))
    print("revocacao_incorreta: " + str(revocacao_incorreta))
    print("revocacao_correta: " + str(revocacao_correta))
    
    #REVOCAÇÃO = 
    f1_sem = (2*precisao_sem*revocacao_sem)/(precisao_sem + revocacao_sem)
    f1_incorreta = (2*precisao_incorreta*revocacao_incorreta)/(precisao_incorreta + revocacao_incorreta)
    f1_correta = (2*precisao_correta*revocacao_correta)/(precisao_correta+revocacao_correta)
    print("f1_sem: " + str(f1_sem))
    print("f1_incorreta: " + str(f1_incorreta))
    print("f1_correta: " + str(f1_correta))

# %%
metricas(Matriz)
# Out:
# acuracia_total: 0.86
# precisao_sem: 0.9090909090909091
# precisao_incorreta : 0.8717948717948718
# precisao_correta: 0.8035714285714286
# revocacao_sem: 1.0
# revocacao_incorreta: 0.68
# revocacao_correta: 0.9
# f1_sem: 0.9523809523809523
# f1_incorreta: 0.7640449438202247
# f1_correta: 0.8490566037735849
