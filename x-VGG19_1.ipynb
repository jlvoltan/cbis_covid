# %% [markdown]
# # Caderno com o modelo 1 - partição 1

# %% [markdown]
# - VGG19

# %% [markdown]
# - O trabalho busca classificar imagens de pessoas nas seguintes classes:
#
#
# 1.   pessoas sem máscara
# 2.   pessoas com máscara incorreta
# 3.   pessoas com máscara correta

# %%
# Usaremos a GPU
import tensorflow as tf

# %%
# tf.test.is_gpu_available()
len(tf.config.list_physical_devices('GPU'))
# Out:
# 1

# %%
print(tf.__version__)
# Out:
# 2.6.0

# %% [markdown]
# # Bibliotecas

# %%
#from tensorflow.keras.optimizers import RMSprop
from keras.preprocessing.image import ImageDataGenerator
import cv2
from keras.models import Sequential
from keras.layers import Conv2D, Input, ZeroPadding2D, BatchNormalization,Activation, MaxPooling2D, Flatten, Dense,Dropout
from keras.models import Model, load_model
from keras.callbacks import TensorBoard, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.utils import shuffle
import imutils
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns
import pandas as pd
from PIL import Image
import pathlib

# %%
AUTOTUNE = tf.data.AUTOTUNE

# %% [markdown]
# - Carregando o dataset de treino

# %%
dataset = os.path.join(os.getcwd(), 'D:/TCC/1/p1') #Onde estão a pasta train e test
# Dataset


tamanho_treinamento_com_errada = len(os.listdir(os.path.join(dataset,'incorreta')))
tamanho_treinamento_com_certa = len(os.listdir(os.path.join(dataset,'correta')))
tamanho_treinamento_sem = len(os.listdir(os.path.join(dataset,'sem')))

print("Classe 1 - sem: " + str(tamanho_treinamento_sem))
print("Classe 2 - incorreta: " + str(tamanho_treinamento_com_errada))
print("Classe 3 - correta: " + str(tamanho_treinamento_com_certa))

# Internamente como é mapeado classe indice vetor:
# 0 correta
# 1 incorreta
# 2 sem
# Out:
# Classe 1 - sem: 8000
# Classe 2 - incorreta: 7624
# Classe 3 - correta: 7683

# %%
ditribuicao_dataset = {'1-Sem': [tamanho_treinamento_sem],'2-Incorreta': [tamanho_treinamento_com_errada],'3-Correta':[tamanho_treinamento_com_certa]}
# Criando um dataframe
df_ditribuicao_dataset = pd.DataFrame(ditribuicao_dataset, index=['total'])
df_ditribuicao_dataset
# Out:
#        1-Sem  2-Incorreta  3-Correta
# total   8000         7624       7683

# %% [markdown]
# # Hiper-parâmetros

# %% [markdown]
# - imagem

# %%
image_width = 150
image_height = 150
image_color_channel = 3
image_size = (image_width, image_height)
image_shape = image_size + (image_color_channel,)
image_color_channel_size = 255
batch_size = 32

# %% [markdown]
# # Pré-processamento

# %% [markdown]
# o 1º problema é que algumas fotos podem estar corrompidas. Iremos excluí-las conforme
# ensinado em https://keras.io/examples/vision/image_classification_from_scratch/

# %% [markdown]
# Adotaremos a separação do conjunto original em 3 partes: Treinamento, Validação e Teste.
#
# - O conjunto de Treinamento será utilizado para o processo de aprendizado,
# - O conjunto de Validação será utilizado para o ajuste de parâmetros, depois de cada época,
# - O conjunto de Teste será utilizado para avaliar o modelo final.
#
# Para isso, o conjunto de treinamento será separado em 90% como treinamento e 10% como validação

# %% [markdown]
# ### Forma: meu próprio pipeline

# %% [markdown]
# - Construir manualmente um tf.data.Dataset semelhante ao criado por tf.keras.utils.image_dataset_from_directory
# - Aqui, conseguirei dividir o dataset em treino e teste

# %% [markdown]
# - Segui o descrito em: https://www.tensorflow.org/tutorials/load_data/images

# %%
data_dir_1 = pathlib.Path(dataset)
data_dir_1
# Out:
# WindowsPath('D:/TCC/1/p1')

# %%
image_count = len(list(data_dir_1.glob('*/*')))   #ou .jpg
print(image_count)
# Out:
# 23307

# %%
list_ds = tf.data.Dataset.list_files(str(data_dir_1) + '/*/*', shuffle=True)
list_ds = list_ds.shuffle(image_count, reshuffle_each_iteration=False)

# %%
for f in list_ds.take(5):
  print(f.numpy())
# Out:
# b'D:\\TCC\\1\\p1\\correta\\57629_Mask.jpg'
# b'D:\\TCC\\1\\p1\\correta\\01250_Mask.jpg'
# b'D:\\TCC\\1\\p1\\incorreta\\26300_Mask_Mouth_Chin.jpg'
# b'D:\\TCC\\1\\p1\\sem\\29838.jpg'
# b'D:\\TCC\\1\\p1\\incorreta\\01722_Mask_Mouth_Chin.jpg'

# %% [markdown]
# Usando a estrutura em árvore (nome das pastas) como classe:

# %%
class_names = np.array(sorted([item.name for item in data_dir_1.glob('*') if item.name != "LICENSE.txt"]))
print(class_names)
# Out:
# ['correta' 'incorreta' 'sem']

# %%
#Estamos com o dataset de treino, ele será dividido em treinamento (80%) e validação (20%)
val_size = int(image_count * 0.2)
train_ds = list_ds.skip(val_size)
val_ds = list_ds.take(val_size)

# %%
# Podemos obter a caredinalidade de um dataset de duas formas

print(tf.data.experimental.cardinality(train_ds).numpy())
print(tf.data.experimental.cardinality(val_ds).numpy())
# Out:
# 18646
# 4661

# %% [markdown]
# - Função curta que converta um caminho de arquivo em um par (img, label) :

# %%
def get_label(file_path):
  # Convert the path to a list of path components
  parts = tf.strings.split(file_path, os.path.sep)
  # The second to last is the class-directory
  one_hot = parts[-2] == class_names
  # Integer encode the label
  return tf.argmax(one_hot)

# %%
def decode_img(img):
  # Convert the compressed string to a 3D uint8 tensor
  img = tf.io.decode_jpeg(img, channels=3)
  # Resize the image to the desired size
  return tf.image.resize(img, [image_height, image_width])

# %%
def process_path(file_path):
  label = get_label(file_path)
  # Load the raw data from the file as a string
  img = tf.io.read_file(file_path)
  img = decode_img(img)
  return img, label

# %% [markdown]
# - criar conjunto image, label

# %%
# Set `num_parallel_calls` so multiple images are loaded/processed in parallel.
train_ds = train_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
for image, label in train_ds.take(1):
  print("Image shape: ", image.numpy().shape)
  print("Label: ", label.numpy())
# Out:
# Image shape:  (150, 150, 3)
# Label:  1

# %% [markdown]
# - Configurar conjunto de dados para desempenho

# %%
def configure_for_performance(ds):
  ds = ds.cache()
  ds = ds.shuffle(buffer_size=1000)
  ds = ds.batch(batch_size)
  ds = ds.prefetch(buffer_size=AUTOTUNE)
  return ds

# %%
train_ds = configure_for_performance(train_ds)
val_ds = configure_for_performance(val_ds)

# %% [markdown]
# - Plotar algumas imagens

# %%
# image_batch, label_batch = next(iter(train_ds))

# plt.figure(figsize=(10, 10))
# for i in range(9):
#   ax = plt.subplot(3, 3, i + 1)
#   plt.imshow(image_batch[i].numpy().astype("uint8"))
#   label = label_batch[i]
#   plt.title(class_names[label])
#   plt.axis("off")

# %%
def plotar_imagens(dataset):
  plt.gcf().clear()
  plt.figure(figsize = (10, 10))
  for imagem, rotulo in dataset.take(1):
    for i in range(6):
      ax = plt.subplot(3, 3, i + 1)
      plt.imshow(imagem[i].numpy().astype('uint8'))
      plt.title(class_names[rotulo[i]])
      plt.axis('off')

# %%
plotar_imagens(train_ds)

# %% [markdown]
# # Modelo

# %% [markdown]
# - HP do modelo

# %%
tx_aprendizagem = 0.0001
epocas = 50

# %% [markdown]
# - Podemos criar uma camada de normalização das imagens:

# %%
# normalization_layer = tf.keras.layers.Rescaling(1./255, input_shape =image_shape)

# %% [markdown]
# - questão de cache das memórias

# %%
train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# Criação do modelo propriamente falando:

# %%
num_classes = 3

# %% [markdown]
# https://www.tensorflow.org/api_docs/python/tf/keras/applications/vgg19/VGG19

# %%
modelo_treinado= tf.keras.applications.vgg19.VGG19(
    include_top=False,
    weights='imagenet',
    input_tensor=None,
    input_shape=(150, 150, 3),
    pooling=None,
    classes=num_classes,
    classifier_activation='softmax'
)


#Normalização do pixel
inputs = tf.keras.Input(shape=(150, 150, 3))
normalizacao = tf.keras.layers.Rescaling(scale=1 / 127.5, offset=-1)
x = normalizacao(inputs)
#Construcao do modelo
# model = Sequential()
# model.add(modelo_treinado)
# )
# model.add()
# model.add()
x = modelo_treinado(x, training=False)
x = tf.keras.layers.Flatten()(x)
x = tf.keras.layers.Dropout(0.2)(x) # Regularize with dropout
x = tf.keras.layers.Dense(150, activation='relu')(x)
outputs = tf.keras.layers.Dense(num_classes, activation='softmax')(x)
model = tf.keras.Model(inputs, outputs)
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 3s 0us/step
# 80150528/80134624 [==============================] - 3s 0us/step
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# rescaling (Rescaling)        (None, 150, 150, 3)       0
# _________________________________________________________________
# vgg19 (Functional)           (None, 4, 4, 512)         20024384
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 150)               1228950
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 453
# =================================================================
# Total params: 21,253,787
# Trainable params: 21,253,787
# Non-trainable params: 0
# _________________________________________________________________

# %%
#otimização
opt = Adam(learning_rate=tx_aprendizagem)

# %%
# METRICS = [
#     tf.keras.metrics.Accuracy(name="acc"),
#     tf.keras.metrics.Precision(name="precision"),
#     tf.keras.metrics.Recall(name="recall"),
# ]

# %%
model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics='acc')   #METRICS)
model.summary()

#sparse_categorical_crossentropy ou 'categorical_crossentropy' na função perda
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# rescaling (Rescaling)        (None, 150, 150, 3)       0
# _________________________________________________________________
# vgg19 (Functional)           (None, 4, 4, 512)         20024384
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 150)               1228950
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 453
# =================================================================
# Total params: 21,253,787
# Trainable params: 21,253,787
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Treinamento

# %% [markdown]
# - Treinando...

# %% [markdown]
# Existem várias maneiras de combater o overfitting no processo de treinamento, p.e.:
# - o aumento de dados
# - adicionará Dropout ao seu modelo.
#
# - Cair fora
# Outra técnica para reduzir o overfitting é introduzir a regularização de dropout na rede.
#
# Quando você aplica dropout a uma camada, ela descarta aleatoriamente (definindo a ativação como zero) um número de unidades de saída da camada durante o processo de treinamento. Dropout recebe um número fracionário como valor de entrada, na forma de 0,1, 0,2, 0,4, etc. Isso significa descartar 10%, 20% ou 40% das unidades de saída aleatoriamente da camada aplicada.

# %%
#Salvando o melhor modelo
checkpoint = ModelCheckpoint('model2-{epoch:03d}.model',monitor='val_accuracy',verbose=0,save_best_only=True,mode='auto')


#Treinando...
history = model.fit(train_ds,
                              epochs=epocas,
                              validation_data=val_ds,
                              callbacks=[checkpoint])
# Out:
# Epoch 1/50
# 583/583 [==============================] - 794s 1s/step - loss: 0.0424 - acc: 0.9869 - val_loss: 0.0035 - val_acc: 0.9991
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 2/50
# 583/583 [==============================] - 514s 877ms/step - loss: 0.0082 - acc: 0.9983 - val_loss: 0.0030 - val_acc: 0.9996
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 3/50
# 583/583 [==============================] - 249s 426ms/step - loss: 0.0081 - acc: 0.9977 - val_loss: 0.0412 - val_acc: 0.9897
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 4/50
# 583/583 [==============================] - 246s 421ms/step - loss: 0.0132 - acc: 0.9966 - val_loss: 0.0031 - val_acc: 0.9998
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 5/50
# 583/583 [==============================] - 246s 422ms/step - loss: 0.0046 - acc: 0.9990 - val_loss: 0.0062 - val_acc: 0.9981
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 6/50
# 583/583 [==============================] - 247s 423ms/step - loss: 0.0136 - acc: 0.9968 - val_loss: 0.0022 - val_acc: 0.9996
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 7/50
# 583/583 [==============================] - 245s 421ms/step - loss: 0.0055 - acc: 0.9987 - val_loss: 0.0019 - val_acc: 0.9996
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 8/50
# 583/583 [==============================] - 245s 420ms/step - loss: 0.0099 - acc: 0.9976 - val_loss: 0.0050 - val_acc: 0.9991
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 9/50
# 583/583 [==============================] - 245s 420ms/step - loss: 0.0041 - acc: 0.9990 - val_loss: 0.0017 - val_acc: 0.9998
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 10/50
# 583/583 [==============================] - 245s 421ms/step - loss: 0.0023 - acc: 0.9997 - val_loss: 0.0015 - val_acc: 0.9998
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 11/50
# 583/583 [==============================] - 246s 422ms/step - loss: 0.0043 - acc: 0.9992 - val_loss: 0.0131 - val_acc: 0.9966
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 12/50
# 583/583 [==============================] - 244s 418ms/step - loss: 0.0119 - acc: 0.9976 - val_loss: 0.0020 - val_acc: 0.9998
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 13/50
# 583/583 [==============================] - 244s 418ms/step - loss: 0.0045 - acc: 0.9987 - val_loss: 0.0024 - val_acc: 0.9994
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 14/50
# 583/583 [==============================] - 244s 418ms/step - loss: 0.0037 - acc: 0.9991 - val_loss: 7.5540e-04 - val_acc: 0.9998
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 15/50
# 583/583 [==============================] - 243s 418ms/step - loss: 0.0030 - acc: 0.9995 - val_loss: 0.1081 - val_acc: 0.9852
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 16/50
# 583/583 [==============================] - 243s 417ms/step - loss: 0.0099 - acc: 0.9981 - val_loss: 0.0018 - val_acc: 0.9996
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 17/50
# 583/583 [==============================] - 243s 417ms/step - loss: 0.0036 - acc: 0.9990 - val_loss: 0.0097 - val_acc: 0.9974
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 18/50
# 583/583 [==============================] - 242s 416ms/step - loss: 0.0049 - acc: 0.9991 - val_loss: 0.0041 - val_acc: 0.9994
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 19/50
# 583/583 [==============================] - 243s 417ms/step - loss: 0.0033 - acc: 0.9993 - val_loss: 0.0019 - val_acc: 0.9996
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 20/50
# 583/583 [==============================] - 243s 417ms/step - loss: 0.0058 - acc: 0.9987 - val_loss: 0.0023 - val_acc: 0.9996
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 21/50
# 583/583 [==============================] - 243s 416ms/step - loss: 0.0023 - acc: 0.9996 - val_loss: 5.3514e-04 - val_acc: 1.0000
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 22/50
# 583/583 [==============================] - 242s 416ms/step - loss: 0.0011 - acc: 0.9997 - val_loss: 8.6658e-05 - val_acc: 1.0000
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 23/50
# 583/583 [==============================] - 243s 417ms/step - loss: 1.0180e-04 - acc: 0.9999 - val_loss: 5.8257e-05 - val_acc: 1.0000
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 24/50
# 583/583 [==============================] - 243s 417ms/step - loss: 1.1408e-05 - acc: 1.0000 - val_loss: 7.5919e-05 - val_acc: 1.0000
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 25/50
# 583/583 [==============================] - 243s 416ms/step - loss: 3.6483e-06 - acc: 1.0000 - val_loss: 9.3499e-05 - val_acc: 1.0000
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 26/50
# 583/583 [==============================] - 243s 416ms/step - loss: 2.1174e-06 - acc: 1.0000 - val_loss: 1.0819e-04 - val_acc: 1.0000
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 27/50
# 583/583 [==============================] - 243s 417ms/step - loss: 1.0330e-06 - acc: 1.0000 - val_loss: 1.2139e-04 - val_acc: 1.0000
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 28/50
# 583/583 [==============================] - 243s 417ms/step - loss: 5.9734e-07 - acc: 1.0000 - val_loss: 1.7420e-04 - val_acc: 0.9998
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 29/50
# 583/583 [==============================] - 243s 416ms/step - loss: 4.3623e-07 - acc: 1.0000 - val_loss: 2.3220e-04 - val_acc: 0.9998
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 30/50
# 583/583 [==============================] - 242s 415ms/step - loss: 2.3050e-07 - acc: 1.0000 - val_loss: 3.1852e-04 - val_acc: 0.9998
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 31/50
# 583/583 [==============================] - 242s 415ms/step - loss: 9.4273e-08 - acc: 1.0000 - val_loss: 3.8766e-04 - val_acc: 0.9998
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 32/50
# 583/583 [==============================] - 243s 416ms/step - loss: 7.6660e-08 - acc: 1.0000 - val_loss: 5.6100e-04 - val_acc: 0.9998
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 33/50
# 583/583 [==============================] - 242s 414ms/step - loss: 4.1571e-08 - acc: 1.0000 - val_loss: 7.0643e-04 - val_acc: 0.9998
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 34/50
# 583/583 [==============================] - 241s 414ms/step - loss: 4.5583e-08 - acc: 1.0000 - val_loss: 9.3680e-04 - val_acc: 0.9998
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 35/50
# 583/583 [==============================] - 241s 414ms/step - loss: 1.0485e-08 - acc: 1.0000 - val_loss: 0.0011 - val_acc: 0.9998
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 36/50
# 583/583 [==============================] - 242s 415ms/step - loss: 1.1802e-08 - acc: 1.0000 - val_loss: 0.0013 - val_acc: 0.9998
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 37/50
# 583/583 [==============================] - 241s 414ms/step - loss: 6.2462e-09 - acc: 1.0000 - val_loss: 0.0014 - val_acc: 0.9998
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 38/50
# 583/583 [==============================] - 242s 415ms/step - loss: 8.1895e-09 - acc: 1.0000 - val_loss: 0.0016 - val_acc: 0.9998
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 39/50
# 583/583 [==============================] - 242s 416ms/step - loss: 3.9638e-09 - acc: 1.0000 - val_loss: 0.0019 - val_acc: 0.9998
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 40/50
# 583/583 [==============================] - 242s 414ms/step - loss: 3.5355e-09 - acc: 1.0000 - val_loss: 0.0019 - val_acc: 0.9998
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 41/50
# 583/583 [==============================] - 241s 414ms/step - loss: 1.7709e-09 - acc: 1.0000 - val_loss: 0.0020 - val_acc: 0.9998
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 42/50
# 583/583 [==============================] - 241s 414ms/step - loss: 1.8802e-08 - acc: 1.0000 - val_loss: 0.0014 - val_acc: 0.9998
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 43/50
# 583/583 [==============================] - 242s 414ms/step - loss: 3.1711e-09 - acc: 1.0000 - val_loss: 0.0014 - val_acc: 0.9998
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 44/50
# 583/583 [==============================] - 241s 414ms/step - loss: 2.4358e-09 - acc: 1.0000 - val_loss: 0.0014 - val_acc: 0.9998
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 45/50
# 583/583 [==============================] - 242s 415ms/step - loss: 2.3527e-09 - acc: 1.0000 - val_loss: 0.0014 - val_acc: 0.9998
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 46/50
# 583/583 [==============================] - 241s 413ms/step - loss: 1.2339e-09 - acc: 1.0000 - val_loss: 0.0014 - val_acc: 0.9998
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 47/50
# 583/583 [==============================] - 241s 413ms/step - loss: 1.1955e-09 - acc: 1.0000 - val_loss: 0.0014 - val_acc: 0.9998
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 48/50
# 583/583 [==============================] - 241s 413ms/step - loss: 9.2063e-10 - acc: 1.0000 - val_loss: 0.0013 - val_acc: 0.9998
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 49/50
# 583/583 [==============================] - 241s 414ms/step - loss: 6.3293e-10 - acc: 1.0000 - val_loss: 0.0012 - val_acc: 0.9998
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 50/50
# 583/583 [==============================] - 241s 413ms/step - loss: 4.0917e-10 - acc: 1.0000 - val_loss: 0.0012 - val_acc: 0.9998
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.

# %%
#Plotar o desempenho
def processo_treinamento():
  accuracy = history.history['acc']
  val_accuracy = history.history['val_acc']
  loss = history.history['loss']
  val_loss = history.history['val_loss']
  epochs_range = range(epocas)
  plt.gcf().clear()
  plt.figure(figsize = (15, 8))
  plt.subplot(1, 2, 1)
  plt.title('Evolução da Acurácia ao Longo do treinamento')
  plt.plot(epochs_range, accuracy, label = 'Training Accuracy')
  plt.plot(epochs_range, val_accuracy, label = 'Validation Accuracy')
  plt.legend(loc = 'lower right')
  plt.subplot(1, 2, 2)
  plt.title('Evolução da Loss ao Longo do treinamento')
  plt.plot(epochs_range, loss, label = 'Training Loss')
  plt.plot(epochs_range, val_loss, label = 'Validation Loss')
  plt.legend(loc = 'lower right')
  plt.savefig("processo-treinamento-vgg19_ab.png", dpi=300)
  plt.show()

# %%
processo_treinamento()  #seria o caso de plotar as outras métricas?

# %% [markdown]
# # Salvar o modelo

# %%
model.save('modelos/model_p1_vgg19_ab')
# Out:
# INFO:tensorflow:Assets written to: modelos/model_p1_vgg19_ab\assets

# %% [markdown]
# # Importando o modelo

# %%
model = load_model('modelos/model_p1_vgg19_ab')

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# rescaling (Rescaling)        (None, 150, 150, 3)       0
# _________________________________________________________________
# vgg19 (Functional)           (None, 4, 4, 512)         20024384
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 150)               1228950
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 453
# =================================================================
# Total params: 21,253,787
# Trainable params: 21,253,787
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Aplicando o modelo a um dataset de teste

# %% [markdown]
# - Nosso dataset de teste:

# %%
# dataset_teste = os.path.join('D:/TCC/1/teste', '')
dataset_teste = os.path.join('D:/artigo/mix', '') #Onde estão a pasta train (p1) e test (p1-teste)
# Dataset

# %%
data_dir_teste= pathlib.Path(dataset_teste)
data_dir_teste
# Out:
# WindowsPath('D:/artigo/mix')

# %%
image_count_t = len(list(data_dir_teste.glob('*/*')))   #ou .jpg
print(image_count_t)
# Out:
# 150

# %%
list_t = tf.data.Dataset.list_files(str(data_dir_teste) + '/*/*', shuffle=False)
list_t = list_t.shuffle(image_count_t, reshuffle_each_iteration=False)

# %%
for f1 in list_t.take(3):
  print(f1.numpy())
# Out:
# b'D:\\artigo\\mix\\sem\\55998.png'
# b'D:\\artigo\\mix\\correta\\428_mask.jpg'
# b'D:\\artigo\\mix\\correta\\36_mask.jpg'

# %%
class_names = np.array(sorted([item.name for item in data_dir_1.glob('*') if item.name != "LICENSE.txt"]))
print(class_names)
# Out:
# ['correta' 'incorreta' 'sem']

# %%
val_size_t = int(image_count_t *0)
teste = list_t.skip(val_size_t)
print(tf.data.experimental.cardinality(teste).numpy())
# Out:
# 150

# %%
# Set `num_parallel_calls` so multiple images are loaded/processed in parallel.
teste  = teste.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
for image, label in teste.take(1):
  print("Image shape: ", image.numpy().shape)
  print("Label: ", label.numpy())
# Out:
# Image shape:  (150, 150, 3)
# Label:  2

# %%
#  Configurar conjunto de dados para desempenho
teste = configure_for_performance(teste)

#  questão de cache das memórias
teste =  teste.cache().prefetch(buffer_size=AUTOTUNE)

# %%
plotar_imagens(teste)

# %%
# teste = tf.keras.utils.image_dataset_from_directory(
#   data_dir_teste,
#   image_size=(image_height, image_width),
#   batch_size=batch_size)

# %%
classe_real = pd.DataFrame(columns=["real"])
ponteiro = 0
for data in teste.as_numpy_iterator():
    a = class_names[data[1]]
    for i in range(a.size):  # de 0 a 31  
        classe_real.loc[i+ponteiro] = a[i]
    ponteiro= classe_real.shape[0]

# %%
classe_real
# Out:
#           real
# 0          sem
# 1    incorreta
# 2      correta
# 3          sem
# 4      correta
# ..         ...
# 145    correta
# 146  incorreta
# 147        sem
# 148        sem
# 149    correta
#
# [150 rows x 1 columns]

# %%
predictions = model.predict(teste)
print(predictions)
# Out:
# [[1.84335276e-18 1.70659404e-16 1.00000000e+00]
#  [4.54961318e-13 5.97273200e-08 9.99999881e-01]
#  [9.06243563e-01 7.65465052e-11 9.37564522e-02]
#  [4.15325533e-16 4.69166874e-14 1.00000000e+00]
#  [7.97627450e-11 2.76526968e-10 1.00000000e+00]
#  [6.61194183e-16 1.67349885e-13 1.00000000e+00]
#  [1.02299891e-17 2.05763573e-15 1.00000000e+00]
#  [3.21956541e-08 1.03112831e-10 1.00000000e+00]
#  [4.53545881e-12 4.67621630e-09 1.00000000e+00]
#  [1.32210767e-17 1.23425120e-15 1.00000000e+00]
#  [4.78545346e-08 5.70504460e-03 9.94294941e-01]
#  [3.91005215e-14 1.79052148e-10 1.00000000e+00]
#  [3.15531238e-12 1.00655140e-09 1.00000000e+00]
#  [2.39944393e-14 1.30517486e-10 1.00000000e+00]
#  [7.18364421e-20 6.70357028e-17 1.00000000e+00]
#  [1.05399922e-18 5.25006406e-17 1.00000000e+00]
#  [1.37524692e-09 1.00000000e+00 7.74457054e-10]
#  [1.88389526e-09 4.33445075e-06 9.99995708e-01]
#  [1.17192715e-15 1.10471777e-12 1.00000000e+00]
#  [1.90947484e-14 4.32441274e-13 1.00000000e+00]
#  [4.31310236e-17 1.93651349e-14 1.00000000e+00]
#  [1.10434932e-19 1.75827612e-17 1.00000000e+00]
#  [6.83766065e-18 7.97072234e-15 1.00000000e+00]
#  [2.08391772e-14 1.02095138e-11 1.00000000e+00]
#  [5.91166131e-17 1.29054736e-14 1.00000000e+00]
#  [1.47540574e-19 4.74424974e-17 1.00000000e+00]
#  [2.66722850e-17 1.20839944e-15 1.00000000e+00]
#  [2.18257560e-16 2.52161383e-13 1.00000000e+00]
#  [9.99858856e-01 5.53423529e-10 1.41072902e-04]
#  [1.19046969e-02 5.04360534e-03 9.83051658e-01]
#  [2.53469692e-20 2.02167243e-17 1.00000000e+00]
#  [4.00741813e-19 1.33793791e-16 1.00000000e+00]
#  [4.18527734e-13 1.35484207e-10 1.00000000e+00]
#  [5.51483465e-18 9.17448596e-16 1.00000000e+00]
#  [8.65321079e-11 1.20028858e-07 9.99999881e-01]
#  [4.86239729e-15 1.86527836e-13 1.00000000e+00]
#  [9.12530617e-16 4.85771146e-13 1.00000000e+00]
#  [5.27123559e-17 3.03084516e-14 1.00000000e+00]
#  [9.56663964e-22 3.05303575e-19 1.00000000e+00]
#  [9.63327640e-10 3.54623785e-06 9.99996424e-01]
#  [1.56584281e-17 5.66164784e-15 1.00000000e+00]
#  [2.49649440e-10 1.10896763e-05 9.99988914e-01]
#  [5.48833948e-14 5.25283428e-11 1.00000000e+00]
#  [1.51915795e-08 6.83712482e-04 9.99316335e-01]
#  [2.13843361e-17 7.36235161e-16 1.00000000e+00]
#  [6.60850556e-18 7.07093840e-16 1.00000000e+00]
#  [8.26939483e-13 1.26729877e-10 1.00000000e+00]
#  [1.32402221e-07 2.78487187e-02 9.72151160e-01]
#  [2.87849827e-10 3.56441210e-09 1.00000000e+00]
#  [1.00838511e-08 2.80956647e-10 1.00000000e+00]
#  [3.36444035e-13 1.05612763e-08 1.00000000e+00]
#  [1.51554103e-13 1.54299004e-10 1.00000000e+00]
#  [3.82313203e-08 3.42046858e-09 1.00000000e+00]
#  [8.41326261e-17 2.97466180e-14 1.00000000e+00]
#  [1.22691688e-18 6.04532550e-16 1.00000000e+00]
#  [9.99774516e-01 2.22362010e-04 3.14444037e-06]
#  [9.65737170e-18 6.04671241e-15 1.00000000e+00]
#  [2.56161195e-13 2.87947582e-10 1.00000000e+00]
#  [1.15487582e-16 1.07415026e-14 1.00000000e+00]
#  [7.36076749e-19 1.22775679e-15 1.00000000e+00]
#  [2.47137827e-18 6.84286048e-16 1.00000000e+00]
#  [2.64229446e-18 2.09683472e-15 1.00000000e+00]
#  [2.09041463e-14 3.38656382e-12 1.00000000e+00]
#  [4.28633664e-16 2.50510875e-13 1.00000000e+00]
#  [3.84391173e-12 5.29483906e-08 1.00000000e+00]
#  [5.02517331e-15 5.53817062e-11 1.00000000e+00]
#  [9.99999762e-01 2.45608874e-07 3.80081522e-09]
#  [1.43758756e-19 3.67834347e-17 1.00000000e+00]
#  [3.60520194e-14 1.68264794e-11 1.00000000e+00]
#  [2.54457016e-19 5.50934672e-18 1.00000000e+00]
#  [1.37115839e-08 8.01909529e-03 9.91980910e-01]
#  [1.07475193e-08 7.72201005e-08 9.99999881e-01]
#  [1.45454819e-14 2.45966806e-11 1.00000000e+00]
#  [3.85755237e-15 1.10161472e-11 1.00000000e+00]
#  [1.03812134e-07 6.50246948e-05 9.99934912e-01]
#  [2.21052073e-15 2.27208812e-12 1.00000000e+00]
#  [1.45745411e-20 1.07929931e-17 1.00000000e+00]
#  [8.06007212e-21 5.90210117e-19 1.00000000e+00]
#  [1.00000000e+00 1.19069979e-23 2.65448576e-20]
#  [2.93763146e-20 4.02402606e-18 1.00000000e+00]
#  [3.36940574e-16 5.45042747e-15 1.00000000e+00]
#  [2.27141626e-16 2.01350184e-14 1.00000000e+00]
#  [5.47882486e-13 1.24158628e-09 1.00000000e+00]
#  [5.34619806e-19 1.15231961e-15 1.00000000e+00]
#  [1.40309788e-18 4.98121706e-16 1.00000000e+00]
#  [8.60450148e-17 1.76891515e-14 1.00000000e+00]
#  [1.00000000e+00 6.17691578e-24 8.56752058e-10]
#  [2.10876630e-19 9.34644278e-17 1.00000000e+00]
#  [3.92994793e-14 1.41001447e-10 1.00000000e+00]
#  [3.42353861e-15 6.22015081e-13 1.00000000e+00]
#  [1.28832644e-14 3.70626229e-12 1.00000000e+00]
#  [2.17920862e-10 3.41166100e-08 1.00000000e+00]
#  [1.83959293e-12 5.95748062e-10 1.00000000e+00]
#  [9.25406873e-15 3.34662398e-12 1.00000000e+00]
#  [1.84931300e-16 1.82213890e-13 1.00000000e+00]
#  [6.18983440e-19 1.13922935e-15 1.00000000e+00]
#  [5.01441944e-12 1.26620958e-09 1.00000000e+00]
#  [2.22041281e-19 5.26864499e-16 1.00000000e+00]
#  [1.57650943e-12 6.36486197e-10 1.00000000e+00]
#  [1.91679961e-09 3.21489187e-14 1.00000000e+00]
#  [9.99999523e-01 5.34254411e-07 2.48515892e-08]
#  [4.13938056e-14 1.00000000e+00 2.24157964e-18]
#  [1.82251033e-17 1.95570273e-15 1.00000000e+00]
#  [3.95475102e-12 6.65834443e-10 1.00000000e+00]
#  [1.22227654e-13 1.99978003e-11 1.00000000e+00]
#  [1.54869136e-19 8.07772143e-18 1.00000000e+00]
#  [1.00000000e+00 2.06613766e-08 1.53248997e-10]
#  [5.93969083e-17 2.16820381e-15 1.00000000e+00]
#  [2.44194647e-11 2.57045343e-07 9.99999762e-01]
#  [1.32362789e-15 2.12477410e-12 1.00000000e+00]
#  [5.61386215e-11 9.29823607e-10 1.00000000e+00]
#  [5.68785478e-18 3.47950822e-15 1.00000000e+00]
#  [2.58936979e-18 4.62412703e-16 1.00000000e+00]
#  [2.60681282e-10 3.62306025e-07 9.99999642e-01]
#  [1.37991825e-17 7.74301447e-15 1.00000000e+00]
#  [6.01330977e-16 4.30778155e-14 1.00000000e+00]
#  [4.67126604e-09 9.96830642e-01 3.16930632e-03]
#  [2.18685825e-17 2.95177027e-15 1.00000000e+00]
#  [2.56685749e-11 3.69005342e-08 1.00000000e+00]
#  [2.65257274e-20 2.88418160e-17 1.00000000e+00]
#  [1.98614151e-18 1.01865354e-16 1.00000000e+00]
#  [3.79025820e-18 1.13161061e-15 1.00000000e+00]
#  [3.96620572e-18 6.22268392e-15 1.00000000e+00]
#  [1.84460470e-18 5.75912365e-16 1.00000000e+00]
#  [5.17771806e-13 4.11484458e-10 1.00000000e+00]
#  [6.82985732e-13 3.09465986e-09 1.00000000e+00]
#  [1.00841661e-14 1.76634193e-11 1.00000000e+00]
#  [1.78386141e-08 9.99999523e-01 4.29739686e-07]
#  [5.21383951e-17 5.62071836e-15 1.00000000e+00]
#  [5.74685851e-15 5.82608350e-10 1.00000000e+00]
#  [3.70234379e-18 3.29600240e-16 1.00000000e+00]
#  [1.62705813e-13 1.60885246e-11 1.00000000e+00]
#  [7.09645349e-07 4.69531436e-08 9.99999285e-01]
#  [5.34689465e-18 1.17028306e-15 1.00000000e+00]
#  [5.02567863e-20 7.28526338e-18 1.00000000e+00]
#  [1.43164349e-20 9.88163939e-18 1.00000000e+00]
#  [7.58116667e-19 1.15364749e-16 1.00000000e+00]
#  [8.05660630e-19 8.15043358e-17 1.00000000e+00]
#  [5.09017628e-09 6.03812305e-06 9.99993920e-01]
#  [9.39979543e-08 6.54475230e-08 9.99999881e-01]
#  [3.35658987e-16 6.00939817e-13 1.00000000e+00]
#  [8.70305480e-21 6.16852519e-19 1.00000000e+00]
#  [5.94592830e-16 7.36307513e-14 1.00000000e+00]
#  [1.56833716e-02 2.79355983e-09 9.84316587e-01]
#  [1.04826531e-18 1.49171806e-16 1.00000000e+00]
#  [1.03676874e-04 2.95847002e-07 9.99896049e-01]
#  [3.26829350e-17 1.00000000e+00 2.74831190e-14]
#  [6.71417606e-14 4.50708117e-11 1.00000000e+00]
#  [2.02852659e-15 2.46485043e-13 1.00000000e+00]
#  [2.66890732e-10 5.22488399e-08 1.00000000e+00]]

# %%
def predicao(predictions):  #predictions é a saída da função predict
    score1 = tf.nn.softmax(predictions)    
    # score1.shape[0]  é a quantidade de predições
    classe = pd.DataFrame(columns=["predito","confianca"])
    for i in range(score1.shape[0]):
        classe.loc[i] = [class_names[np.argmax(score1[i])],100*np.max(score1[i])]   
    return classe

# %%
def get_labels_from_tfdataset(tfdataset, batched=False):
    labels = list(map(lambda x: x[1], tfdataset)) # Get labels 
    if not batched:
         return tf.concat(labels, axis=0) # concat the list of batched labels
    return class_names[labels]

# %%
get_labels_from_tfdataset(teste)
# Out:
# <tf.Tensor: shape=(150,), dtype=int64, numpy=
# array([2, 1, 0, 2, 0, 2, 2, 0, 2, 2, 1, 1, 1, 1, 2, 2, 1, 1, 1, 2, 2, 2,
#        1, 0, 0, 1, 2, 1, 0, 0, 1, 2, 0, 0, 1, 0, 2, 2, 0, 1, 2, 0, 2, 0,
#        2, 2, 1, 0, 0, 0, 1, 2, 0, 1, 2, 0, 1, 1, 2, 1, 2, 0, 1, 0, 0, 1,
#        0, 2, 0, 0, 0, 0, 2, 1, 0, 1, 1, 2, 0, 1, 0, 1, 1, 1, 1, 1, 0, 2,
#        0, 2, 2, 1, 0, 1, 1, 1, 0, 2, 1, 0, 0, 1, 0, 0, 0, 2, 0, 2, 1, 0,
#        0, 1, 2, 0, 2, 2, 1, 2, 1, 1, 2, 2, 0, 2, 1, 0, 2, 1, 2, 1, 1, 0,
#        1, 2, 2, 2, 2, 2, 0, 0, 1, 2, 1, 0, 2, 0, 1, 2, 2, 0], dtype=int64)>

# %%
classe_predita = predicao(predictions)
classe_predita
# Out:
#        predito  confianca
# 0          sem  57.611686
# 1          sem  57.611686
# 2      correta  54.118639
# 3          sem  57.611686
# 4          sem  57.611686
# ..         ...        ...
# 145        sem  57.607877
# 146  incorreta  57.611686
# 147        sem  57.611686
# 148        sem  57.611686
# 149        sem  57.611686
#
# [150 rows x 2 columns]

# %%
resultado_df = pd.concat([classe_real, classe_predita],axis=1)
resultado_df
# Out:
#           real    predito  confianca
# 0          sem        sem  57.611686
# 1    incorreta        sem  57.611686
# 2      correta    correta  54.118639
# 3          sem        sem  57.611686
# 4      correta        sem  57.611686
# ..         ...        ...        ...
# 145    correta        sem  57.607877
# 146  incorreta  incorreta  57.611686
# 147        sem        sem  57.611686
# 148        sem        sem  57.611686
# 149    correta        sem  57.611686
#
# [150 rows x 3 columns]

# %% [markdown]
# - Avaliação

# %%
model.evaluate(teste, return_dict=True)
# Out:
# 5/5 [==============================] - 1s 116ms/step - loss: 15.0870 - acc: 0.4200
# {'loss': 15.08696460723877, 'acc': 0.41999998688697815}

# %%
dataset_test_loss, dataset_test_accuracy = model.evaluate(teste)
print('Dataset Test Loss: %s' % dataset_test_loss)
print('Dataset Test Accuracy: %s' % dataset_test_accuracy)
# Out:
# 5/5 [==============================] - 1s 116ms/step - loss: 15.0870 - acc: 0.4200
# Dataset Test Loss: 15.08696460723877
# Dataset Test Accuracy: 0.41999998688697815

# %% [markdown]
# Obs.: Para as outras métricas, utilizar o arquivo avaliacao. Ele irá gerar uma matriz de confusão. Em seguida, com base nos elementos dessa matriz, ele realiza os cálculos das métricas
